# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset, dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male','smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf','poly','sigmoid','linear'],
            'C':[10,100,1000],'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for parameter {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.148358      0.020045         0.047275        0.005477       10
# 1     1700.012815    244.687438         0.013932        0.002122       10
# 2        0.086564      0.008605         0.016070        0.001566       10
# 3        0.106304      0.005711         0.014534        0.002466       10
# 4        0.096381      0.010981         0.038579        0.001013       10
# 5        0.097805      0.013903         0.013694        0.000507       10
# 6        0.120789      0.014050         0.024402        0.002797       10
# 7        0.101683      0.007796         0.014635        0.002021       10
# 8        0.147299      0.027159         0.045046        0.008231      100
# 9     1991.928414    558.211175         0.010637        0.003706      100
# 10       0.082552      0.004113         0.015687        0.001742      100
# 11       0.253546      0.048056         0.016142        0.002012      100
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=float(input("sex male 0 or 1 :"))
smoker_input=float(input("smoker yes 0 or 1 :"))
# Out:
# Age: 14
# BMI: 23
# children: 1
# sex male 0 or 1 : 1
# smoker yes 0 or 1 : 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16082.57622331]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
